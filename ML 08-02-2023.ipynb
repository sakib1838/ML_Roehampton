# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'C:\Users\sakiba\Downloads\bill_authentication.csv')
dataset.head(20)
# Out:
#     Variance  Skewness  Curtosis  Entropy  Class
# 0    3.62160    8.6661  -2.80730 -0.44699      0
# 1    4.54590    8.1674  -2.45860 -1.46210      0
# 2    3.86600   -2.6383   1.92420  0.10645      0
# 3    3.45660    9.5228  -4.01120 -3.59440      0
# 4    0.32924   -4.4552   4.57180 -0.98880      0
# 5    4.36840    9.6718  -3.96060 -3.16250      0
# 6    3.59120    3.0129   0.72888  0.56421      0
# 7    2.09220   -6.8100   8.46360 -0.60216      0
# 8    3.20320    5.7588  -0.75345 -0.61251      0
# 9    1.53560    9.1772  -2.27180 -0.73535      0
# 10   1.22470    8.7779  -2.21350 -0.80647      0
# 11   3.98990   -2.7066   2.39460  0.86291      0
# 12   1.89930    7.6625   0.15394 -3.11080      0
# 13  -1.57680   10.8430   2.54620 -2.93620      0
# 14   3.40400    8.7261  -2.99150 -0.57242      0
# 15   4.67650   -3.3895   3.48960  1.47710      0
# 16   2.67190    3.0646   0.37158  0.58619      0
# 17   0.80355    2.8473   4.34390  0.60170      0
# ...

# %%
dataset.shape
# Out:
# (1372, 5)

# %%
X = dataset.drop(['Class'], axis=1)
Y = dataset[['Class']]
# Out:
#       Class
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 1367      1
# 1368      1
# 1369      1
# 1370      1
# 1371      1
#
# [1372 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       148
#            1       0.98      0.98      0.98       127
#
#     accuracy                           0.98       275
#    macro avg       0.98      0.98      0.98       275
# weighted avg       0.98      0.98      0.98       275

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=clf.classes_)
disp.plot()

plt.show()

# %%
print(cm)
# Out:
# [[145   3]
#  [  3 124]]

# %% [markdown]
# # ACTIVITY

# %%
activity_dataset = pd.read_csv(r'C:\Users\sakiba\Downloads\PastHires.csv')
activity_dataset.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

activity_dataset['Employed?']= le.fit_transform(activity_dataset['Employed?'])
activity_dataset

# %%
activity_dataset['Level of Education']= le.fit_transform(activity_dataset['Level of Education'])
activity_dataset
# Out:
#     Years Experience  Employed?  Previous employers Level of Education  \
# 0                 10          1                   4                 BS
# 1                  0          0                   0                 BS
# 2                  7          0                   6                 BS
# 3                  2          1                   1                 MS
# 4                 20          0                   2                PhD
# 5                  0          0                   0                PhD
# 6                  5          1                   2                 MS
# 7                  3          0                   1                 BS
# 8                 15          1                   5                 BS
# 9                  0          0                   0                 BS
# 10                 1          0                   1                PhD
# 11                 4          1                   1                 BS
# ...

# %%
activity_dataset['Top-tier school']= le.fit_transform(activity_dataset['Top-tier school'])
activity_dataset
# Out:
#     Years Experience  Employed?  Previous employers  Level of Education  \
# 0                 10          1                   4                   0
# 1                  0          0                   0                   0
# 2                  7          0                   6                   0
# 3                  2          1                   1                   1
# 4                 20          0                   2                   2
# 5                  0          0                   0                   2
# 6                  5          1                   2                   1
# 7                  3          0                   1                   0
# 8                 15          1                   5                   0
# 9                  0          0                   0                   0
# 10                 1          0                   1                   2
# 11                 4          1                   1                   0
# ...

# %%
activity_dataset['Interned']= le.fit_transform(activity_dataset['Interned'])
activity_dataset
# Out:
#     Years Experience  Employed?  Previous employers  Level of Education  \
# 0                 10          1                   4                   0
# 1                  0          0                   0                   0
# 2                  7          0                   6                   0
# 3                  2          1                   1                   1
# 4                 20          0                   2                   2
# 5                  0          0                   0                   2
# 6                  5          1                   2                   1
# 7                  3          0                   1                   0
# 8                 15          1                   5                   0
# 9                  0          0                   0                   0
# 10                 1          0                   1                   2
# 11                 4          1                   1                   0
# ...

# %%
activity_dataset['Hired']= le.fit_transform(activity_dataset['Hired'])
activity_dataset
# Out:
#     Years Experience  Employed?  Previous employers  Level of Education  \
# 0                 10          1                   4                   0
# 1                  0          0                   0                   0
# 2                  7          0                   6                   0
# 3                  2          1                   1                   1
# 4                 20          0                   2                   2
# 5                  0          0                   0                   2
# 6                  5          1                   2                   1
# 7                  3          0                   1                   0
# 8                 15          1                   5                   0
# 9                  0          0                   0                   0
# 10                 1          0                   1                   2
# 11                 4          1                   1                   0
# ...

# %%
AX = activity_dataset.drop(['Hired'],axis=1)
AY = activity_dataset[['Hired']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(AX, AY, test_size=0.20)

# %%
from sklearn.tree import DecisionTreeClassifier
DT_clf = DecisionTreeClassifier()
DT_clf.fit(X_train,y_train)

DT_y_pred = DT_clf.predict(X_test)

# %%
# Out:
# (13, 7)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, DT_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
RF_clf = RandomForestClassifier(max_depth=2)
RF_clf.fit(X_train,y_train)

RF_y_pred = RF_clf.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, RF_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# C:\Windows\Temp\ipykernel_23228\301419984.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_clf.fit(X_train,y_train)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.naive_bayes import GaussianNB
GNB_clf = GaussianNB()
GNB_clf.fit(X_train,y_train)

GNB_y_pred = GNB_clf.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, RF_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ### Implementing 3 different classification model on PatHires.csv we can define that the accuracy of the models are same which is 67 %.
